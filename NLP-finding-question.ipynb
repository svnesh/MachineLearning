# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import nltk
import re
import warnings
warnings.filterwarnings('ignore')
pd.options.display.max_rows = 75

# %%
df_full = pd.read_csv('sample.csv')

# %%
df_full.shape
# Out:
# (93, 7)

# %%
df_full.head()
# Out:
#    tweet_id     author_id  inbound                      created_at  \
# 0  119237    105834        True     Wed Oct 11 06:55:44 +0000 2017
# 1  119238    ChaseSupport  False    Wed Oct 11 13:25:49 +0000 2017
# 2  119239    105835        True     Wed Oct 11 13:00:09 +0000 2017
# 3  119240    VirginTrains  False    Tue Oct 10 15:16:08 +0000 2017
# 4  119241    105836        True     Tue Oct 10 15:17:21 +0000 2017
#
#                                                                                                                                                   text  \
# 0  @AppleSupport causing the reply to be disregarded and the tapped notification under the keyboard is opened😡😡😡
# 1  @105835 Your business means a lot to us. Please DM your name, zip code and additional details about your concern. ^RR https://t.co/znUu1VJn9r
# 2  @76328 I really hope you all change but I'm sure you won't! Because you don't have to!
# ...

# %%
df = df_full[['text']]

# %%
def changeToLower(text):
    return str(text).lower()

df['text_lower'] = df['text'].apply(lambda text:changeToLower(text))
df.head()
# Out:
#                                                                                                                                                   text  \
# 0  @AppleSupport causing the reply to be disregarded and the tapped notification under the keyboard is opened😡😡😡
# 1  @105835 Your business means a lot to us. Please DM your name, zip code and additional details about your concern. ^RR https://t.co/znUu1VJn9r
# 2  @76328 I really hope you all change but I'm sure you won't! Because you don't have to!
# 3  @105836 LiveChat is online at the moment - https://t.co/SY94VtU8Kq or contact 03331 031 031 option 1, 4, 3 (Leave a message) to request a call back
# 4  @VirginTrains see attached error message. I've tried leaving a voicemail several times in the past week https://t.co/NxVZjlYx1k
#
#                                                                                                                                             text_lower
# ...

# %%
def clearnonascii(text):
    return ''.join([i if ord(i) < 128 else '' for i in text])

df['text_withoutasci'] = df['text_lower'].apply(lambda text:clearnonascii(text))
df.head()
# Out:
#                                                                                                                                                   text  \
# 0  @AppleSupport causing the reply to be disregarded and the tapped notification under the keyboard is opened😡😡😡
# 1  @105835 Your business means a lot to us. Please DM your name, zip code and additional details about your concern. ^RR https://t.co/znUu1VJn9r
# 2  @76328 I really hope you all change but I'm sure you won't! Because you don't have to!
# 3  @105836 LiveChat is online at the moment - https://t.co/SY94VtU8Kq or contact 03331 031 031 option 1, 4, 3 (Leave a message) to request a call back
# 4  @VirginTrains see attached error message. I've tried leaving a voicemail several times in the past week https://t.co/NxVZjlYx1k
#
#                                                                                                                                             text_lower  \
# ...

# %%
df.drop(columns=['text_lower'], inplace=True)
df.head()
# Out:
#                                                                                                                                                   text  \
# 0  @AppleSupport causing the reply to be disregarded and the tapped notification under the keyboard is opened😡😡😡
# 1  @105835 Your business means a lot to us. Please DM your name, zip code and additional details about your concern. ^RR https://t.co/znUu1VJn9r
# 2  @76328 I really hope you all change but I'm sure you won't! Because you don't have to!
# 3  @105836 LiveChat is online at the moment - https://t.co/SY94VtU8Kq or contact 03331 031 031 option 1, 4, 3 (Leave a message) to request a call back
# 4  @VirginTrains see attached error message. I've tried leaving a voicemail several times in the past week https://t.co/NxVZjlYx1k
#
#                                                                                                                                       text_withoutasci
# ...

# %%
twitacc = re.compile('(@\w+\s)')
httpsite = re.compile('((http|www.)\S+)')
def removeTwitacc(text):
    str1 = twitacc.sub('', str(text))
    return httpsite.sub('URL', str1)

df['text_withoutlinkid'] = df['text_withoutasci'].apply(lambda text:removeTwitacc(text))
df.head()
# Out:
#                                                                                                                                                   text  \
# 0  @AppleSupport causing the reply to be disregarded and the tapped notification under the keyboard is opened😡😡😡
# 1  @105835 Your business means a lot to us. Please DM your name, zip code and additional details about your concern. ^RR https://t.co/znUu1VJn9r
# 2  @76328 I really hope you all change but I'm sure you won't! Because you don't have to!
# 3  @105836 LiveChat is online at the moment - https://t.co/SY94VtU8Kq or contact 03331 031 031 option 1, 4, 3 (Leave a message) to request a call back
# 4  @VirginTrains see attached error message. I've tried leaving a voicemail several times in the past week https://t.co/NxVZjlYx1k
#
#                                                                                                                                       text_withoutasci  \
# ...

# %%
import string
PUNCTUATIONS = string.punctuation

def removepunct(text):
    return text.translate(text.maketrans('','', PUNCTUATIONS))

df['text_withoutpunct'] = df['text_withoutlinkid'].apply(lambda text:removepunct(text))
df.head()
# Out:
#                                                                                                                                                   text  \
# 0  @AppleSupport causing the reply to be disregarded and the tapped notification under the keyboard is opened😡😡😡
# 1  @105835 Your business means a lot to us. Please DM your name, zip code and additional details about your concern. ^RR https://t.co/znUu1VJn9r
# 2  @76328 I really hope you all change but I'm sure you won't! Because you don't have to!
# 3  @105836 LiveChat is online at the moment - https://t.co/SY94VtU8Kq or contact 03331 031 031 option 1, 4, 3 (Leave a message) to request a call back
# 4  @VirginTrains see attached error message. I've tried leaving a voicemail several times in the past week https://t.co/NxVZjlYx1k
#
#                                                                                                                                       text_withoutasci  \
# ...
